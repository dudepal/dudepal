# %% [markdown]
# <a href="https://colab.research.google.com/github/dudepal/dudepal/blob/main/Audio_Course_BuildfastwithAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Notebook by Build Fast with AI
#
# Check out our [Crash Course on Generative AI](https://www.buildfastwithai.com/genai-course)

# %%
# !pip install -qU elevenlabs
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.5 MB/s eta 0:00:00

# %%
from elevenlabs import generate, play, set_api_key

# set_api_key("")

# %% [markdown]
# ### Convert text to voice

# %%
audio = generate(
    text = "Type whatever want",
    voice = "Adam"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = generate(
    text = "Type whatever want",
    voice = "Adam"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# changed voice

audio = generate(
    text = "Welcome to Crash Course on Generative AI by Build Fast with AI.",
    voice = "Rachel"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Getting responses in Hindi

# %%
audio = generate(
    text = "व्याख्यान में आपका स्वागत है!",
    voice = "Rachel",
    model = "eleven_multilingual_v2"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# using Multilingual Model
#

audio = generate(
    text = "सभी को नमस्कार, आशा है कि आप कुछ नया सीख रहे होंगे।",
    voice = "Rachel",
    model = "eleven_multilingual_v2"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = generate(
    text = "మీరు ఆస్వాదిస్తున్నారని ఆశిస్తున్నాను",
    voice = "Rachel",
    model = "eleven_multilingual_v2"
)

play(audio, notebook = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
